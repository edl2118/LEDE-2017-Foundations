# %% [markdown]
# # Exercise: The Price of Weed
#
# #### Summary
#
# Find out how marijuana prices change over time and place in the United States
#
# #### Data Source(s)
#
# Data scraped from http://www.priceofweed.com/, GitHub repository at, https://github.com/frankbi/price-of-weed
#
# Marijuana laws by state from https://data.world/sya/marijuana-laws-by-state
#
# #### Files
#
# - Lots of csvs in data/, formatted at DDMMYYY.csv, daily prices for different states
# - `state_marijuana_laws_10_2016.csv`, marijuana laws by state
#
# #### Data dictionary
#
# - **State** the state name
# - **HighQ** high quality marijuana, price per ounce
# - **HighQN** high quality marijuana, sample size
# - **MedQ** medium quality marijuana, price per ounce
# - **MedQN** medium quality marijuana, sample size
# - **LowQ** low quality marijuana, price per ounce
# - **LowQN** low quality marijuana, sample size
#
# #### Skills
#
# - Reading in many many files
# - Combining multiple dataframes
# - Cleaning up columns
# - Customizing matplotlib graphs

# %% [markdown]
# # Read in `data/weedprices01012015.csv`

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import glob
import matplotlib.ticker as ticker

# %%
df=pd.read_csv("data/weedprices01012015.csv")

# %%
df.shape
# Out:
# (51, 7)

# %%
df.dtypes
# Out:
# State      object
# HighQ     float64
# HighQN      int64
# MedQ      float64
# MedQN       int64
# LowQ       object
# LowQN       int64
# dtype: object

# %%
df.head()
# Out:
#         State   HighQ  HighQN    MedQ  MedQN                           LowQ  \
# 0     Alabama  337.54    1539  208.24   1463  I feel bad for these guys -->
# 1      Alaska  303.02     350  270.45    475  I feel bad for these guys -->
# 2     Arizona  298.51    2638  209.43   2426  I feel bad for these guys -->
# 3    Arkansas  341.68     846  207.20    836  I feel bad for these guys -->
# 4  California  243.96   16512  189.35  19151  I feel bad for these guys -->
#
#    LowQN
# 0    182
# 1     37
# 2    306
# 3    145
# 4   1096

# %% [markdown]
# ## Cleaning things up
#
# I have no idea what the whole "I feel bad for these guys" means, but *it certainly isn't good data*. It should probably be NaN instead: I'll let you decide how you're going to fix that one.

# %%
df["LowQ"].replace("I feel bad for these guys -->",np.nan,inplace=True)

# %%
df.head()
# Out:
#         State   HighQ  HighQN    MedQ  MedQN  LowQ  LowQN
# 0     Alabama  337.54    1539  208.24   1463   NaN    182
# 1      Alaska  303.02     350  270.45    475   NaN     37
# 2     Arizona  298.51    2638  209.43   2426   NaN    306
# 3    Arkansas  341.68     846  207.20    836   NaN    145
# 4  California  243.96   16512  189.35  19151   NaN   1096

# %% [markdown]
# ## Graph the top 10 least expensive states for high quality marijuana

# %%
df.sort_values("HighQ", ascending=False).tail(10).plot(x="State", y="HighQ", kind="barh")

# %% [markdown]
# ## Graph the top 5 least expensive and the top 5 most expensive states for high quality marijuana, in one graph
#
# You'll probably need to make a new dataframe out of the first 5 and last 5.

# %%
least_expensive = df.sort_values("HighQ", ascending=True).head()

# %%
most_expensive = df.sort_values("HighQ", ascending=False).head()

# %%
df_combined = pd.concat([least_expensive, most_expensive], ignore_index=True)

# %%
df_combined.sort_values(by="HighQ").plot(x="State", y="HighQ", kind="barh", figsize=(10,10))

# %% [markdown]
# ## Now go back and make one of those graphs look nice!
#
# - Add a title
# - Add a label to the bottom axis
# - Remove the label on the left axis
# - Remove the legend
# - Get rid of the boxes around everything
# - Remove most of the tick marks
# - Add dollar signs for the bottom
#
# For tips, just ask me and/or use
#
# - https://matplotlib.org/gallery.html
# - Especially https://matplotlib.org/examples/ticks_and_spines/spines_demo.html
#
# To format numbers, you can use something that might look a little familiar
#
# ```python
# import matplotlib.ticker as ticker
# ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("${x:,.0f}"))
# ```

# %%
ax = df_combined.sort_values(by="HighQ").plot(x="State", y="HighQ", kind="barh", figsize=(10,10),legend=False)
ax.set_title("Where to find the most expensive and least expensive high quality weed in the US ")
ax.set_xlabel("high quality marijuana, price per ounce")
ax.set_ylabel("")
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.spines["top"].set_visible(False)
ax.spines["bottom"].set_visible(False)
ax.yaxis.set_ticks_position("none")
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("${x:.0f}"))

# %% [markdown]
# # Reading in many many files
#
# ## Finding the filenames
#
# Make a list of the filenames of every single CSV files inside of the `data` directory. Don't type them out.
#
# If you do this correctly you will have a list of **491** filenames.

# %%
ls data/
# Out:
# today/                  weedprices11022015.csv* weedprices21012015.csv*
# weedprices01012014.csv* weedprices11032014.csv* weedprices21022014.csv*
# weedprices01012015.csv* weedprices11042014.csv* weedprices21032014.csv*
# weedprices01022014.csv* weedprices11052014.csv* weedprices21042014.csv*
# weedprices01022015.csv* weedprices11052015.csv* weedprices21052014.csv*
# weedprices01032014.csv* weedprices11062014.csv* weedprices21052015.csv*
# weedprices01042014.csv* weedprices11062015.csv* weedprices21062014.csv*
# weedprices01052014.csv* weedprices11072014.csv* weedprices21062015.csv*
# weedprices01062014.csv* weedprices11072015.csv* weedprices21072014.csv*
# weedprices01062015.csv* weedprices11082014.csv* weedprices21072015.csv*
# weedprices01072014.csv* weedprices11092014.csv* weedprices21082014.csv*
# weedprices01072015.csv* weedprices11102014.csv* weedprices21092014.csv*
# weedprices01082014.csv* weedprices11112014.csv* weedprices21102014.csv*
# weedprices01092014.csv* weedprices11122014.csv* weedprices21112014.csv*
# weedprices01102014.csv* weedprices12012014.csv* weedprices21122014.csv*
# weedprices01112014.csv* weedprices12012015.csv* weedprices22012014.csv*
# weedprices01122014.csv* weedprices12022014.csv* weedprices22012015.csv*
# weedprices02012014.csv* weedprices12022015.csv* weedprices22022014.csv*
# weedprices02012015.csv* weedprices12032014.csv* weedprices22032014.csv*
# weedprices02022014.csv* weedprices12042014.csv* weedprices22042014.csv*
# weedprices02022015.csv* weedprices12052014.csv* weedprices22052014.csv*
# weedprices02032014.csv* weedprices12052015.csv* weedprices22052015.csv*
# weedprices02042014.csv* weedprices12062014.csv* weedprices22062014.csv*
# weedprices02052014.csv* weedprices12062015.csv* weedprices22062015.csv*
# weedprices02062014.csv* weedprices12072014.csv* weedprices22072014.csv*
# weedprices02062015.csv* weedprices12072015.csv* weedprices22072015.csv*
# weedprices02072014.csv* weedprices12082014.csv* weedprices22082014.csv*
# weedprices02072015.csv* weedprices12092014.csv* weedprices22092014.csv*
# weedprices02092014.csv* weedprices12102014.csv* weedprices22102014.csv*
# weedprices02102014.csv* weedprices12112014.csv* weedprices22112014.csv*
# weedprices02112014.csv* weedprices12122014.csv* weedprices22122014.csv*
# weedprices02122014.csv* weedprices13012014.csv* weedprices23012014.csv*
# weedprices03012014.csv* weedprices13012015.csv* weedprices23012015.csv*
# weedprices03012015.csv* weedprices13022014.csv* weedprices23022014.csv*
# weedprices03022014.csv* weedprices13022015.csv* weedprices23032014.csv*
# weedprices03022015.csv* weedprices13032014.csv* weedprices23042014.csv*
# weedprices03032014.csv* weedprices13042014.csv* weedprices23052014.csv*
# weedprices03042014.csv* weedprices13052014.csv* weedprices23052015.csv*
# weedprices03052014.csv* weedprices13052015.csv* weedprices23062014.csv*
# weedprices03062014.csv* weedprices13062014.csv* weedprices23062015.csv*
# weedprices03062015.csv* weedprices13062015.csv* weedprices23072014.csv*
# weedprices03072014.csv* weedprices13072014.csv* weedprices23072015.csv*
# weedprices03072015.csv* weedprices13072015.csv* weedprices23082014.csv*
# weedprices03082014.csv* weedprices13082014.csv* weedprices23092014.csv*
# weedprices03092014.csv* weedprices13092014.csv* weedprices23102014.csv*
# weedprices03102014.csv* weedprices13102014.csv* weedprices23112014.csv*
# weedprices03112014.csv* weedprices13112014.csv* weedprices23122014.csv*
# weedprices03122014.csv* weedprices13122014.csv* weedprices24012014.csv*
# weedprices04012014.csv* weedprices14012014.csv* weedprices24012015.csv*
# weedprices04012015.csv* weedprices14012015.csv* weedprices24022014.csv*
# weedprices04022014.csv* weedprices14022014.csv* weedprices24032014.csv*
# weedprices04022015.csv* weedprices14022015.csv* weedprices24042014.csv*
# weedprices04032014.csv* weedprices14032014.csv* weedprices24052014.csv*
# weedprices04042014.csv* weedprices14042014.csv* weedprices24052015.csv*
# weedprices04052014.csv* weedprices14052014.csv* weedprices24062014.csv*
# weedprices04062014.csv* weedprices14052015.csv* weedprices24062015.csv*
# weedprices04062015.csv* weedprices14062014.csv* weedprices24072014.csv*
# weedprices04072014.csv* weedprices14062015.csv* weedprices24082014.csv*
# weedprices04072015.csv* weedprices14072014.csv* weedprices24092014.csv*
# weedprices04082014.csv* weedprices14072015.csv* weedprices24102014.csv*
# weedprices04092014.csv* weedprices14082014.csv* weedprices24112014.csv*
# weedprices04102014.csv* weedprices14092014.csv* weedprices24122014.csv*
# weedprices04112014.csv* weedprices14102014.csv* weedprices25012014.csv*
# weedprices04122014.csv* weedprices14112014.csv* weedprices25012015.csv*
# weedprices05012014.csv* weedprices14122014.csv* weedprices25022014.csv*
# weedprices05012015.csv* weedprices15012014.csv* weedprices25032014.csv*
# weedprices05022014.csv* weedprices15012015.csv* weedprices25042014.csv*
# weedprices05022015.csv* weedprices15022014.csv* weedprices25052014.csv*
# weedprices05032014.csv* weedprices15022015.csv* weedprices25052015.csv*
# weedprices05042014.csv* weedprices15032014.csv* weedprices25062014.csv*
# weedprices05052014.csv* weedprices15042014.csv* weedprices25062015.csv*
# weedprices05062014.csv* weedprices15052014.csv* weedprices25072014.csv*
# weedprices05062015.csv* weedprices15052015.csv* weedprices25082014.csv*
# weedprices05072014.csv* weedprices15062014.csv* weedprices25092014.csv*
# weedprices05072015.csv* weedprices15062015.csv* weedprices25102014.csv*
# weedprices05082014.csv* weedprices15072014.csv* weedprices25112014.csv*
# weedprices05092014.csv* weedprices15072015.csv* weedprices25122014.csv*
# weedprices05102014.csv* weedprices15082014.csv* weedprices26012014.csv*
# weedprices05112014.csv* weedprices15092014.csv* weedprices26012015.csv*
# weedprices05122014.csv* weedprices15102014.csv* weedprices26022014.csv*
# weedprices06012014.csv* weedprices15112014.csv* weedprices26032014.csv*
# weedprices06012015.csv* weedprices15122014.csv* weedprices26042014.csv*
# weedprices06022014.csv* weedprices16012014.csv* weedprices26052014.csv*
# weedprices06022015.csv* weedprices16012015.csv* weedprices26052015.csv*
# weedprices06032014.csv* weedprices16022014.csv* weedprices26062014.csv*
# weedprices06042014.csv* weedprices16022015.csv* weedprices26062015.csv*
# weedprices06052014.csv* weedprices16032014.csv* weedprices26072014.csv*
# weedprices06062014.csv* weedprices16042014.csv* weedprices26082014.csv*
# weedprices06062015.csv* weedprices16052014.csv* weedprices26092014.csv*
# weedprices06072014.csv* weedprices16052015.csv* weedprices26102014.csv*
# weedprices06072015.csv* weedprices16062014.csv* weedprices26112014.csv*
# weedprices06082014.csv* weedprices16062015.csv* weedprices26122014.csv*
# weedprices06092014.csv* weedprices16072014.csv* weedprices27012014.csv*
# weedprices06102014.csv* weedprices16072015.csv* weedprices27012015.csv*
# weedprices06112014.csv* weedprices16082014.csv* weedprices27022014.csv*
# weedprices06122014.csv* weedprices16092014.csv* weedprices27032014.csv*
# weedprices07012014.csv* weedprices16102014.csv* weedprices27042014.csv*
# weedprices07012015.csv* weedprices16112014.csv* weedprices27052014.csv*
# weedprices07022014.csv* weedprices16122014.csv* weedprices27052015.csv*
# weedprices07022015.csv* weedprices17012014.csv* weedprices27062014.csv*
# weedprices07032014.csv* weedprices17012015.csv* weedprices27062015.csv*
# weedprices07042014.csv* weedprices17022014.csv* weedprices27072014.csv*
# weedprices07052014.csv* weedprices17032014.csv* weedprices27082014.csv*
# weedprices07062014.csv* weedprices17042014.csv* weedprices27092014.csv*
# weedprices07062015.csv* weedprices17052014.csv* weedprices27102014.csv*
# weedprices07072014.csv* weedprices17052015.csv* weedprices27112014.csv*
# weedprices07072015.csv* weedprices17062014.csv* weedprices27122013.csv*
# weedprices07082014.csv* weedprices17062015.csv* weedprices27122014.csv*
# weedprices07092014.csv* weedprices17072014.csv* weedprices28012014.csv*
# weedprices07102014.csv* weedprices17072015.csv* weedprices28012015.csv*
# weedprices07112014.csv* weedprices17082014.csv* weedprices28022014.csv*
# weedprices07122014.csv* weedprices17092014.csv* weedprices28032014.csv*
# weedprices08012014.csv* weedprices17102014.csv* weedprices28042014.csv*
# weedprices08012015.csv* weedprices17112014.csv* weedprices28052014.csv*
# weedprices08022014.csv* weedprices17122014.csv* weedprices28052015.csv*
# weedprices08022015.csv* weedprices18012014.csv* weedprices28062014.csv*
# weedprices08032014.csv* weedprices18012015.csv* weedprices28062015.csv*
# weedprices08042014.csv* weedprices18022014.csv* weedprices28072014.csv*
# weedprices08052014.csv* weedprices18032014.csv* weedprices28082014.csv*
# weedprices08062014.csv* weedprices18042014.csv* weedprices28092014.csv*
# weedprices08062015.csv* weedprices18052014.csv* weedprices28102014.csv*
# weedprices08072014.csv* weedprices18052015.csv* weedprices28112014.csv*
# weedprices08072015.csv* weedprices18062014.csv* weedprices28122013.csv*
# weedprices08082014.csv* weedprices18062015.csv* weedprices28122014.csv*
# weedprices08092014.csv* weedprices18072014.csv* weedprices29012014.csv*
# weedprices08102014.csv* weedprices18072015.csv* weedprices29012015.csv*
# weedprices08112014.csv* weedprices18082014.csv* weedprices29032014.csv*
# weedprices08122014.csv* weedprices18092014.csv* weedprices29042014.csv*
# weedprices09012014.csv* weedprices18102014.csv* weedprices29052014.csv*
# weedprices09012015.csv* weedprices18112014.csv* weedprices29052015.csv*
# weedprices09022014.csv* weedprices18122014.csv* weedprices29062014.csv*
# weedprices09022015.csv* weedprices19012014.csv* weedprices29062015.csv*
# weedprices09032014.csv* weedprices19012015.csv* weedprices29072014.csv*
# weedprices09042014.csv* weedprices19022014.csv* weedprices29082014.csv*
# weedprices09052014.csv* weedprices19032014.csv* weedprices29092014.csv*
# weedprices09062014.csv* weedprices19042014.csv* weedprices29102014.csv*
# weedprices09062015.csv* weedprices19052014.csv* weedprices29112014.csv*
# weedprices09072014.csv* weedprices19052015.csv* weedprices29122013.csv*
# weedprices09072015.csv* weedprices19062014.csv* weedprices29122014.csv*
# weedprices09082014.csv* weedprices19062015.csv* weedprices30012014.csv*
# weedprices09092014.csv* weedprices19072014.csv* weedprices30012015.csv*
# weedprices09102014.csv* weedprices19072015.csv* weedprices30032014.csv*
# weedprices09112014.csv* weedprices19082014.csv* weedprices30042014.csv*
# weedprices09122014.csv* weedprices19092014.csv* weedprices30052014.csv*
# weedprices10012014.csv* weedprices19102014.csv* weedprices30052015.csv*
# weedprices10012015.csv* weedprices19112014.csv* weedprices30062014.csv*
# weedprices10022014.csv* weedprices19122014.csv* weedprices30062015.csv*
# weedprices10022015.csv* weedprices20012014.csv* weedprices30072014.csv*
# weedprices10032014.csv* weedprices20012015.csv* weedprices30082014.csv*
# weedprices10042014.csv* weedprices20022014.csv* weedprices30092014.csv*
# weedprices10052014.csv* weedprices20032014.csv* weedprices30102014.csv*
# weedprices10052015.csv* weedprices20042014.csv* weedprices30112014.csv*
# weedprices10062014.csv* weedprices20052014.csv* weedprices30122013.csv*
# weedprices10062015.csv* weedprices20052015.csv* weedprices30122014.csv*
# weedprices10072014.csv* weedprices20062014.csv* weedprices31012014.csv*
# weedprices10072015.csv* weedprices20062015.csv* weedprices31012015.csv*
# weedprices10082014.csv* weedprices20072014.csv* weedprices31032014.csv*
# weedprices10092014.csv* weedprices20072015.csv* weedprices31052014.csv*
# weedprices10102014.csv* weedprices20082014.csv* weedprices31052015.csv*
# weedprices10112014.csv* weedprices20092014.csv* weedprices31072014.csv*
# weedprices10122014.csv* weedprices20102014.csv* weedprices31082014.csv*
# weedprices11012014.csv* weedprices20112014.csv* weedprices31102014.csv*
# weedprices11012015.csv* weedprices20122014.csv* weedprices31122013.csv*
# weedprices11022014.csv* weedprices21012014.csv* weedprices31122014.csv*

# %%
#use glob to get a list of files
files = glob.glob("data/*.csv")

# %%
len(files)
# Out:
# 491

# %% [markdown]
# ## Turn them into dataframes
#
# Read each of them in, converting them to a **list of dataframes**. Save as `price_dfs`.
#
# - Tip: List comprehensions would be good here

# %%
#use a list comprehension to get a list of dataframes
price_dfs = [pd.read_csv(file) for file in files]

# %%
len(price_dfs)
# Out:
# 491

# %% [markdown]
# ## Examing the results
#
# Look at the first 2 rows of the first dataframe.
#
# Look at the first 2 rows of the last dataframe.
#
# **If we combined them, could we tell them apart?**

# %%
#Let's look at our first dataframe
price_dfs[0][:2]
# Out:
#      State    HighQ  HighQN     MedQ  MedQN     LowQ  LowQN
# 0  Alabama  $339.06    1042  $198.64    933  $149.49    123
# 1   Alaska  $288.75     252   $260.6    297  $388.58     26

# %%
#Let's look at our last dataframe
price_dfs[-1][:2]
# Out:
#      State   HighQ  HighQN    MedQ  MedQN                           LowQ  \
# 0  Alabama  337.54    1539  208.15   1460  I feel bad for these guys -->
# 1   Alaska  303.02     350  270.45    475  I feel bad for these guys -->
#
#    LowQN
# 0    182
# 1     37

# %% [markdown]
# ## Making them identifiable
#
# Each dataframe needs to have a column thats says the date. Or, actually... let's just save the filename as a column.
#
# You **could** do it like this.
#
# ```python
# # Take the first dataframe, which was made from the first filename
# # Create a new 'filename' column using the first filename
# price_dfs[0]['filename'] = filenames[0]
# # Take the second dataframe, which was made from the second filename
# # Create a new 'filename' column using the second filename
# price_dfs[1]['filename'] = filenames[1]
# # Take the third dataframe, which was made from the third filename
# # Create a new 'filename' column using the third filename
# price_dfs[2]['filename'] = filenames[2]
# ```
#
# But that way is **not any fun**, and would take too long. I have a faster way.

# %%
#use zip to loop through as many lists as you need to at the same time
#it's going to go through every single one of our files and dataframes
#and make a new column in every dataframe called filename with the file's name

for df,file in zip (price_dfs, files):
    df["filename"] = file

# %%
price_dfs[0][:2]
# Out:
#      State    HighQ  HighQN     MedQ  MedQN     LowQ  LowQN  \
# 0  Alabama  $339.06    1042  $198.64    933  $149.49    123
# 1   Alaska  $288.75     252   $260.6    297  $388.58     26
#
#                       filename
# 0  data/weedprices01012014.csv
# 1  data/weedprices01012014.csv

# %%
price_dfs[-1].tail()
# Out:
#             State   HighQ  HighQN    MedQ  MedQN  \
# 46       Virginia  364.98    3513  293.12   3079
# 47     Washington  233.05    3337  189.92   3562
# 48  West Virginia  359.35     551  224.03    545
# 49      Wisconsin  350.52    2244  272.71   2221
# 50        Wyoming  322.27     131  351.86    197
#
#                              LowQ  LowQN                     filename
# 46  I feel bad for these guys -->    284  data/weedprices31122014.csv
# 47  I feel bad for these guys -->    160  data/weedprices31122014.csv
# 48  I feel bad for these guys -->     60  data/weedprices31122014.csv
# 49  I feel bad for these guys -->    167  data/weedprices31122014.csv
# 50  I feel bad for these guys -->     12  data/weedprices31122014.csv

# %% [markdown]
# ## Combine all 491 dataframes into one dataframe
#
# Confirm it has **24990 rows and 8 columns.**

# %%
combined_dfs= pd.concat(price_dfs,ignore_index=True)

# %%
combined_dfs.shape
# Out:
# (24990, 8)

# %%
combined_dfs["LowQ"].replace("I feel bad for these guys -->",np.nan,inplace=True)

# %% [markdown]
# ## Pull out the day, month and year from each filename
#
# Do **not** store it back yet!

# %%
#pull out the dd, mm, yy separately
#if you capture more than one thing, pandas will return a DataFrame
combined_dfs["filename"].astype(str).str.extract("data/weedprices(\d\d)(\d\d)(\d\d\d\d)")
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   This is separate from the ipykernel package so we can avoid doing imports until
#         0   1     2
# 0      01  01  2014
# 1      01  01  2014
# 2      01  01  2014
# 3      01  01  2014
# 4      01  01  2014
# 5      01  01  2014
# 6      01  01  2014
# 7      01  01  2014
# 8      01  01  2014
# 9      01  01  2014
# 10     01  01  2014
# 11     01  01  2014
# 12     01  01  2014
# 13     01  01  2014
# 14     01  01  2014
# 15     01  01  2014
# 16     01  01  2014
# 17     01  01  2014
# 18     01  01  2014
# 19     01  01  2014
# 20     01  01  2014
# 21     01  01  2014
# 22     01  01  2014
# 23     01  01  2014
# 24     01  01  2014
# 25     01  01  2014
# 26     01  01  2014
# 27     01  01  2014
# 28     01  01  2014
# 29     01  01  2014
# ...    ..  ..   ...
# 24960  31  12  2014
# 24961  31  12  2014
# 24962  31  12  2014
# 24963  31  12  2014
# 24964  31  12  2014
# 24965  31  12  2014
# 24966  31  12  2014
# 24967  31  12  2014
# 24968  31  12  2014
# 24969  31  12  2014
# 24970  31  12  2014
# 24971  31  12  2014
# 24972  31  12  2014
# 24973  31  12  2014
# 24974  31  12  2014
# 24975  31  12  2014
# 24976  31  12  2014
# 24977  31  12  2014
# 24978  31  12  2014
# 24979  31  12  2014
# 24980  31  12  2014
# 24981  31  12  2014
# 24982  31  12  2014
# 24983  31  12  2014
# 24984  31  12  2014
# 24985  31  12  2014
# 24986  31  12  2014
# 24987  31  12  2014
# 24988  31  12  2014
# 24989  31  12  2014
#
# [24990 rows x 3 columns]

# %% [markdown]
# ## Okay, now add all three columns back at once
#
# You should rename the columns first!

# %%
#add them each back in as separate columns
dates_df =combined_dfs["filename"].astype(str).str.extract("data/weedprices(\d\d)(\d\d)(\d\d\d\d)").rename(columns={0:"day",1:"month", 2:"year"})
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)

# %%
#renamed columns
dates_df.head()
# Out:
#   day month  year
# 0  01    01  2014
# 1  01    01  2014
# 2  01    01  2014
# 3  01    01  2014
# 4  01    01  2014

# %%
#combine date stamp into one column
dates_df["date"]= dates_df["day"] + "/" + dates_df["month"] + "/" + dates_df["year"]
dates_df.head()
# Out:
#   day month  year        date
# 0  01    01  2014  01/01/2014
# 1  01    01  2014  01/01/2014
# 2  01    01  2014  01/01/2014
# 3  01    01  2014  01/01/2014
# 4  01    01  2014  01/01/2014

# %%
#use axis=1 to tell pandas to stack side by side using concat
final_df = pd.concat([dates_df, combined_dfs], axis=1)

# %%
final_df.head()
# Out:
#   day month  year        date       State    HighQ HighQN     MedQ  MedQN  \
# 0  01    01  2014  01/01/2014     Alabama  $339.06   1042  $198.64    933
# 1  01    01  2014  01/01/2014      Alaska  $288.75    252   $260.6    297
# 2  01    01  2014  01/01/2014     Arizona  $303.31   1941  $209.35   1625
# 3  01    01  2014  01/01/2014    Arkansas  $361.85    576  $185.62    544
# 4  01    01  2014  01/01/2014  California  $248.78  12096  $193.56  12812
#
#       LowQ LowQN                     filename
# 0  $149.49   123  data/weedprices01012014.csv
# 1  $388.58    26  data/weedprices01012014.csv
# 2  $189.45   222  data/weedprices01012014.csv
# 3  $125.87   112  data/weedprices01012014.csv
# 4  $192.92   778  data/weedprices01012014.csv

# %% [markdown]
# ## Plot the change in marijuana prices in Oregon over time

# %%
final_df["HighQ"] = final_df["HighQ"].astype(str).str.replace("$","").astype(float)

# %%
final_df.head()
# Out:
#   day month  year        date       State   HighQ HighQN     MedQ  MedQN  \
# 0  01    01  2014  01/01/2014     Alabama  339.06   1042  $198.64    933
# 1  01    01  2014  01/01/2014      Alaska  288.75    252   $260.6    297
# 2  01    01  2014  01/01/2014     Arizona  303.31   1941  $209.35   1625
# 3  01    01  2014  01/01/2014    Arkansas  361.85    576  $185.62    544
# 4  01    01  2014  01/01/2014  California  248.78  12096  $193.56  12812
#
#       LowQ LowQN                     filename
# 0  $149.49   123  data/weedprices01012014.csv
# 1  $388.58    26  data/weedprices01012014.csv
# 2  $189.45   222  data/weedprices01012014.csv
# 3  $125.87   112  data/weedprices01012014.csv
# 4  $192.92   778  data/weedprices01012014.csv

# %%
oregon_df = final_df[final_df["State"] == "Oregon"]
oregon_df.head()
# Out:
#     day month  year        date   State   HighQ HighQN     MedQ MedQN  \
# 31   01    01  2014  01/01/2014  Oregon  213.49   1612  $188.55  1336
# 82   01    01  2015  01/01/2015  Oregon  205.80   2179    180.9  2018
# 133  01    02  2014  01/02/2014  Oregon  212.44   1677  $188.96  1384
# 184  01    02  2015  01/02/2015  Oregon  205.32   2232   180.47  2091
# 235  01    03  2014  01/03/2014  Oregon  212.01   1731   $188.5  1450
#
#         LowQ LowQN                     filename
# 31   $175.87    61  data/weedprices01012014.csv
# 82       NaN    95  data/weedprices01012015.csv
# 133  $174.52    65  data/weedprices01022014.csv
# 184      NaN    99  data/weedprices01022015.csv
# 235  $169.34    68  data/weedprices01032014.csv

# %%
oregon_df.groupby("date")["HighQ"].sum().plot(x="date", y="HighQ", figsize=(10,10))

# %%
#soma converted the date_stamp into datetime ... ???

# %% [markdown]
# ## Plot the change in marijuana prices in all states over time

# %%
final_df.groupby("State").plot(x="date", y="HighQ")
# Out:
# /usr/local/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# State
# Alabama                 Axes(0.125,0.125;0.775x0.755)
# Alaska                  Axes(0.125,0.125;0.775x0.755)
# Arizona                 Axes(0.125,0.125;0.775x0.755)
# Arkansas                Axes(0.125,0.125;0.775x0.755)
# California              Axes(0.125,0.125;0.775x0.755)
# Colorado                Axes(0.125,0.125;0.775x0.755)
# Connecticut             Axes(0.125,0.125;0.775x0.755)
# Delaware                Axes(0.125,0.125;0.775x0.755)
# District of Columbia    Axes(0.125,0.125;0.775x0.755)
# Florida                 Axes(0.125,0.125;0.775x0.755)
# Georgia                 Axes(0.125,0.125;0.775x0.755)
# Hawaii                  Axes(0.125,0.125;0.775x0.755)
# Idaho                   Axes(0.125,0.125;0.775x0.755)
# Illinois                Axes(0.125,0.125;0.775x0.755)
# Indiana                 Axes(0.125,0.125;0.775x0.755)
# Iowa                    Axes(0.125,0.125;0.775x0.755)
# Kansas                  Axes(0.125,0.125;0.775x0.755)
# Kentucky                Axes(0.125,0.125;0.775x0.755)
# Louisiana               Axes(0.125,0.125;0.775x0.755)
# Maine                   Axes(0.125,0.125;0.775x0.755)
# Maryland                Axes(0.125,0.125;0.775x0.755)
# Massachusetts           Axes(0.125,0.125;0.775x0.755)
# Michigan                Axes(0.125,0.125;0.775x0.755)
# Minnesota               Axes(0.125,0.125;0.775x0.755)
# Mississippi             Axes(0.125,0.125;0.775x0.755)
# Missouri                Axes(0.125,0.125;0.775x0.755)
# Montana                 Axes(0.125,0.125;0.775x0.755)
# Nebraska                Axes(0.125,0.125;0.775x0.755)
# Nevada                  Axes(0.125,0.125;0.775x0.755)
# New Hampshire           Axes(0.125,0.125;0.775x0.755)
# New Jersey              Axes(0.125,0.125;0.775x0.755)
# New Mexico              Axes(0.125,0.125;0.775x0.755)
# New York                Axes(0.125,0.125;0.775x0.755)
# North Carolina          Axes(0.125,0.125;0.775x0.755)
# North Dakota            Axes(0.125,0.125;0.775x0.755)
# Ohio                    Axes(0.125,0.125;0.775x0.755)
# Oklahoma                Axes(0.125,0.125;0.775x0.755)
# Oregon                  Axes(0.125,0.125;0.775x0.755)
# Pennsylvania            Axes(0.125,0.125;0.775x0.755)
# Rhode Island            Axes(0.125,0.125;0.775x0.755)
# South Carolina          Axes(0.125,0.125;0.775x0.755)
# South Dakota            Axes(0.125,0.125;0.775x0.755)
# Tennessee               Axes(0.125,0.125;0.775x0.755)
# Texas                   Axes(0.125,0.125;0.775x0.755)
# Utah                    Axes(0.125,0.125;0.775x0.755)
# Vermont                 Axes(0.125,0.125;0.775x0.755)
# Virginia                Axes(0.125,0.125;0.775x0.755)
# Washington              Axes(0.125,0.125;0.775x0.755)
# West Virginia           Axes(0.125,0.125;0.775x0.755)
# Wisconsin               Axes(0.125,0.125;0.775x0.755)
# Wyoming                 Axes(0.125,0.125;0.775x0.755)
# dtype: object
