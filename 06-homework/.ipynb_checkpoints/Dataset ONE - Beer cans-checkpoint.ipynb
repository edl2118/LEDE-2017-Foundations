# %% [markdown]
# # A dataset about cans of beer.
#
# Data from http://craftcans.com/

# %% [markdown]
# ## Do your importing and your setup

# %%
import pandas as pd

# %%
# %matplotlib inline

# %% [markdown]
# ## Read in the file `craftcans.csv`, and look at the first rows

# %%
ls
# Out:
# Dataset ONE - Beer cans.ipynb
# Dataset TWO - Dogs.ipynb
# NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx
# boro_population.csv
# boros.csv
# craftcans.csv
# dogs.csv
# zipcodes-neighborhoods.csv

# %%
df = pd.read_csv('craftcans.csv')

# %%
df.head()
# Out:
#             Beer            Brewery         Location               Style  \
# 0   Get Together  NorthGate Brewing  Minneapolis, MN        American IPA
# 1  Maggie's Leap  NorthGate Brewing  Minneapolis, MN  Milk / Sweet Stout
# 2     Wall's End  NorthGate Brewing  Minneapolis, MN   English Brown Ale
# 3        Pumpion  NorthGate Brewing  Minneapolis, MN         Pumpkin Ale
# 4     Stronghold  NorthGate Brewing  Minneapolis, MN     American Porter
#
#      Size    ABV  IBUs
# 0  16 oz.  4.50%  50.0
# 1  16 oz.  4.90%  26.0
# 2  16 oz.  4.80%  19.0
# 3  16 oz.  6.00%  38.0
# 4  16 oz.  6.00%  25.0

# %% [markdown]
# ## How many rows do you have in the data? What are the column types?

# %%
df.shape
# Out:
# (2416, 7)

# %%
df.dtypes
# Out:
# Beer         object
# Brewery      object
# Location     object
# Style        object
# Size         object
# ABV          object
# IBUs        float64
# dtype: object

# %% [markdown]
# # Checking out breweries
#
# Where does beer come from????

# %%
df['Location'].value_counts()
# Out:
# Grand Rapids, MI           66
# Chicago, IL                55
# Portland, OR               52
# Indianapolis, IN           43
# San Diego, CA              42
# Boulder, CO                41
# Denver, CO                 40
# Brooklyn, NY               38
# Seattle, WA                35
# Longmont, CO               33
# San Francisco, CA          32
# Tampa, FL                  31
# Stevens Point, WI          30
# Austin, TX                 25
# Fort Collins, CO           22
# Boston, MA                 21
# Cincinnati, OH             21
# Aurora, IN                 20
# Chandler, AZ               19
# Eagle, CO                  19
# Saint Louis, MO            19
# Manhattan, KS              18
# Missoula, MT               18
# Davenport, IA              18
# Boonville, CA              18
# Salt Lake City, UT         17
# Boise, ID                  17
# Astoria, OR                16
# San Antonio, TX            16
# Durango, CO                16
#                            ..
# ...

# %% [markdown]
# ## What are the top 10 producers of cans of beer?

# %%
df['Brewery'].value_counts().head(10)
# Out:
# Brewery Vivant                62
# Oskar Blues Brewery           46
# Sun King Brewing Company      38
# Cigar City Brewing Company    25
# Sixpoint Craft Ales           24
# Hopworks Urban Brewery        23
# Stevens Point Brewery         22
# Great Crescent Brewery        20
# 21st Amendment Brewery        20
# Bonfire Brewing Company       19
# Name: Brewery, dtype: int64

# %% [markdown]
# ## What is the most common size of beer?
#
# The answer won't be pretty - we'll learn to clean it up in a week or two.

# %%
df['Size'].value_counts()
# Out:
# 12 oz.               1507
# 16 oz.                814
# 24 oz.                 21
# 16 oz. Alumi-Tek®      15
# 19.2 oz.               14
# 12 oz                  14
# 16 oz                  12
# 32 oz.                  5
# 12 oz. Slimline         1
# 12 ounce                1
# 12 OZ.                  1
# 12 & 16 oz.             1
# 24 oz. "Silo Can"       1
# 19.2                    1
# 8.4 oz.                 1
# 16.9 oz.                1
# Name: Size, dtype: int64

# %% [markdown]
# ## What is the most common ABV? (alcohol by volume)

# %%
df['ABV'].value_counts().head()
# Out:
# 5.00%    215
# 5.50%    158
# 6.00%    125
# 6.50%    123
# 5.20%    107
# Name: ABV, dtype: int64

# %% [markdown]
# ## Oh, weird, ABV isn't a number. Convert it to a number for me, please.
#
# It's going to take three steps:
#
# 1. List just the ABV of every row
# 2. Remove the % symbol
# 3. Convert it to a `float`
# 4. Save it into a new column. Or the same column, if you're feeling wild.
#
# Although it *also* turns out that there's some bad data in there. We'll need to clean that up, too.

# %%
df[:5]
# Out:
#             Beer            Brewery         Location               Style  \
# 0   Get Together  NorthGate Brewing  Minneapolis, MN        American IPA
# 1  Maggie's Leap  NorthGate Brewing  Minneapolis, MN  Milk / Sweet Stout
# 2     Wall's End  NorthGate Brewing  Minneapolis, MN   English Brown Ale
# 3        Pumpion  NorthGate Brewing  Minneapolis, MN         Pumpkin Ale
# 4     Stronghold  NorthGate Brewing  Minneapolis, MN     American Porter
#
#      Size    ABV  IBUs
# 0  16 oz.  4.50%  50.0
# 1  16 oz.  4.90%  26.0
# 2  16 oz.  4.80%  19.0
# 3  16 oz.  6.00%  38.0
# 4  16 oz.  6.00%  25.0

# %%
#to change ABV permanently, we need to save it back to the column
df['ABV_new'] = df['ABV'].str.replace('%','')

# %%
df.head()
# Out:
#             Beer            Brewery         Location               Style  \
# 0   Get Together  NorthGate Brewing  Minneapolis, MN        American IPA
# 1  Maggie's Leap  NorthGate Brewing  Minneapolis, MN  Milk / Sweet Stout
# 2     Wall's End  NorthGate Brewing  Minneapolis, MN   English Brown Ale
# 3        Pumpion  NorthGate Brewing  Minneapolis, MN         Pumpkin Ale
# 4     Stronghold  NorthGate Brewing  Minneapolis, MN     American Porter
#
#      Size    ABV  IBUs ABV_new
# 0  16 oz.  4.50%  50.0    4.50
# 1  16 oz.  4.90%  26.0    4.90
# 2  16 oz.  4.80%  19.0    4.80
# 3  16 oz.  6.00%  38.0    6.00
# 4  16 oz.  6.00%  25.0    6.00

# %%
#we couldn't convert some rows into float because some of the ABV values are ???
df[df['ABV_new']=='???'].head()
# Out:
#                 Beer                     Brewery           Location  \
# 94           Bastian  James Page Brewing Company  Stevens Point, WI
# 199  Professor Black            Blue Owl Brewing         Austin, TX
# 200      Little Boss            Blue Owl Brewing         Austin, TX
# 201       Van Dayum!            Blue Owl Brewing         Austin, TX
# 202    Spirit Animal            Blue Owl Brewing         Austin, TX
#
#                         Style    Size  ABV  IBUs ABV_new
# 94        American Strong Ale  12 oz.  ???   NaN     ???
# 199            American Stout  12 oz.  ???   NaN     ???
# 200   American Pale Wheat Ale  12 oz.  ???   NaN     ???
# 201  American Amber / Red Ale  12 oz.  ???   NaN     ???
# 202   American Pale Ale (APA)  12 oz.  ???   NaN     ???

# %%
#we cannot convert ABV into float because some of the rows have missing data (???) 
#so when we read in the file we need to say read the values in as NaN
df = pd.read_csv('craftcans.csv', na_values=["Unknown", "-999", "???"])

# %%
df[df['ABV']=='???'].head()
# Out:
# Empty DataFrame
# Columns: [Beer, Brewery, Location, Style, Size, ABV, IBUs, ABV_new]
# Index: []

# %%
df['ABV_new'] = df['ABV'].str.replace('%','').astype(float)

# %%
df['ABV_new'].dtypes
# Out:
# dtype('float64')

# %%
df[:5]
# Out:
#             Beer            Brewery         Location               Style  \
# 0   Get Together  NorthGate Brewing  Minneapolis, MN        American IPA
# 1  Maggie's Leap  NorthGate Brewing  Minneapolis, MN  Milk / Sweet Stout
# 2     Wall's End  NorthGate Brewing  Minneapolis, MN   English Brown Ale
# 3        Pumpion  NorthGate Brewing  Minneapolis, MN         Pumpkin Ale
# 4     Stronghold  NorthGate Brewing  Minneapolis, MN     American Porter
#
#      Size    ABV  IBUs  ABV_new
# 0  16 oz.  4.50%  50.0      4.5
# 1  16 oz.  4.90%  26.0      4.9
# 2  16 oz.  4.80%  19.0      4.8
# 3  16 oz.  6.00%  38.0      6.0
# 4  16 oz.  6.00%  25.0      6.0

# %%
df.mode()
# Out:
#               Beer         Brewery          Location         Style    Size  \
# 0  Nonstop Hef Hop  Brewery Vivant  Grand Rapids, MI  American IPA  12 oz.
#
#      ABV  IBUs  ABV_new
# 0  5.00%  20.0      5.0

# %% [markdown]
# # Looking at location
#
# Brooklyn used to produce 80% of the country's beer! Let's see if it's still true.

# %% [markdown]
# ## What are the top 10 cities in the US for canned craft beer?

# %%
df['Location'].value_counts().head(10)
# Out:
# Grand Rapids, MI    66
# Chicago, IL         55
# Portland, OR        52
# Indianapolis, IN    43
# San Diego, CA       42
# Boulder, CO         41
# Denver, CO          40
# Brooklyn, NY        38
# Seattle, WA         35
# Longmont, CO        33
# Name: Location, dtype: int64

# %% [markdown]
# ## List all of the beer from Brooklyn, NY

# %%
Brooklyn = df[df['Location'] == 'Brooklyn, NY']

# %%
Brooklyn.head()
# Out:
#               Beer              Brewery      Location                   Style  \
# 115         4Beans  Sixpoint Craft Ales  Brooklyn, NY           Baltic Porter
# 210         Jammer  Sixpoint Craft Ales  Brooklyn, NY                    Gose
# 246        Abigale  Sixpoint Craft Ales  Brooklyn, NY        Belgian Pale Ale
# 404  Nomader Weiss    Evil Twin Brewing  Brooklyn, NY      Berliner Weissbier
# 421            Rad  Sixpoint Craft Ales  Brooklyn, NY  Fruit / Vegetable Beer
#
#                 Size     ABV  IBUs  ABV_new
# 115           12 oz.  10.00%  52.0     10.0
# 210  12 oz. Slimline   4.20%  16.0      4.2
# 246           12 oz.   8.00%   NaN      8.0
# 404           12 oz.   4.00%   NaN      4.0
# 421           16 oz.   3.20%   7.0      3.2

# %% [markdown]
# ## What brewery in Brooklyn puts out the most cans of beer?

# %%
Brooklyn['Brewery'].value_counts().head(1)
# Out:
# Sixpoint Craft Ales    24
# Name: Brewery, dtype: int64

# %% [markdown]
# ## What are the five most popular styles of beer produced by Sixpoint?

# %%
Brooklyn.groupby('Brewery')['Beer'].value_counts().groupby(level=0).nlargest(n=5)
# Out:
# Brewery              Brewery              Beer
# Brooklyn Brewery     Brooklyn Brewery     East India Pale Ale                2
#                                           Brooklyn Lager (12 oz.)            1
#                                           Brooklyn Lager (16 oz.)            1
#                                           Brooklyn Summer Ale                1
#                                           Brooklyn Summer Ale (2011)         1
# Evil Twin Brewing    Evil Twin Brewing    Bikini Beer                        1
#                                           Hipster Ale (Two Roads Brewing)    1
#                                           Hipster Ale (Westbrook Brewing)    1
#                                           Molotov Lite                       1
#                                           Nomader Weiss                      1
# KelSo Beer Company   KelSo Beer Company   KelSo India Pale Ale               1
# ...

# %% [markdown]
# ## List all of the breweries in New York state. Then count them.

# %%
df[df['Location'].str.contains('NY', na=False)]
# Out:
#                                   Beer                     Brewery  \
# 115                             4Beans         Sixpoint Craft Ales
# 210                             Jammer         Sixpoint Craft Ales
# 246                            Abigale         Sixpoint Craft Ales
# 404                      Nomader Weiss           Evil Twin Brewing
# 421                                Rad         Sixpoint Craft Ales
# 439                       Molotov Lite           Evil Twin Brewing
# 588                            Bengali         Sixpoint Craft Ales
# 598                           8 Barrel             Chatham Brewing
# 599                        Oktoberfest             Chatham Brewing
# 628                          Cream Ale    Newburgh Brewing Company
# 653                      Montauk Light   Southampton Publick House
# 713                      Sensi Harvest         Sixpoint Craft Ales
# 768                 Montauk Summer Ale     Montauk Brewing Company
# ...

# %%
df['Location'].str.contains('NY', na=False).sum()
# Out:
# 74

# %%
#count how many of each brewery exists in NY

NY_brewery = df[df['Location'].str.contains('NY', na=False)]

# %%
NY_brewery['Brewery'].value_counts()
# Out:
# Sixpoint Craft Ales              24
# Matt Brewing Company             13
# Brooklyn Brewery                  6
# Evil Twin Brewing                 5
# Butternuts Beer and Ale           4
# Blue Point Brewing Company        4
# The Bronx Brewery                 3
# KelSo Beer Company                3
# Montauk Brewing Company           2
# Bomb Beer Company                 2
# Chatham Brewing                   2
# Upstate Brewing Company           2
# Dundee Brewing Company            1
# Newburgh Brewing Company          1
# Southampton Publick House         1
# The Manhattan Brewing Company     1
# Name: Brewery, dtype: int64

# %% [markdown]
# # Measuring International Bitterness Units
#
# IBU stands for [International Bitterness Unit](http://www.thebrewenthusiast.com/ibus/), and while a lot of places like to brag about having the most bitter beer (it's an American thing!), IBUs don't necessary *mean anything*.
#
# Let's look at how different beers have different IBU measurements.

# %% [markdown]
# ## What is the average IBU measurement across all beers?

# %%
df['IBUs'].mean()
# Out:
# 42.713167259786474

# %% [markdown]
# ## Draw the distribution of IBU measurements, but with *thirty* bins instead of the default of 10

# %%
df['IBUs'].hist(bins=30)

# %% [markdown]
# ## List all of the beers with IBUs above the 75th percentile

# %%
df['IBUs'].describe()
# Out:
# count    1405.000000
# mean       42.713167
# std        25.954066
# min         4.000000
# 25%        21.000000
# 50%        35.000000
# 75%        64.000000
# max       138.000000
# Name: IBUs, dtype: float64

# %%
df[df['IBUs'] > 64]
# Out:
#                                    Beer                           Brewery  \
# 6                        Citra Ass Down         Against the Grain Brewery
# 7                        London Balling         Against the Grain Brewery
# 14                          Rico Sauvin         Against the Grain Brewery
# 17                         Pile of Face         Against the Grain Brewery
# 21                           Excess IPL          Jack's Abby Craft Lagers
# 22                       Hoponius Union          Jack's Abby Craft Lagers
# 24                       Habitus (2014)         Mike Hess Brewing Company
# 25                                Solis         Mike Hess Brewing Company
# 27                              Habitus         Mike Hess Brewing Company
# 46                  Yeti Imperial Stout      Great Divide Brewing Company
# 59    98 Problems (Cuz A Hop Ain't One)            Perrin Brewing Company
# 62                         Train Hopper       Witch's Hat Brewing Company
# ...

# %% [markdown]
# ## List all of the beers with IBUs below the 25th percentile

# %%
df[df['IBUs'] < 21]
# Out:
#                                         Beer  \
# 2                                 Wall's End
# 12                                  Sho'nuff
# 13                               Bloody Show
# 18                            The Brown Note
# 19                               House Lager
# 20                              Leisure Time
# 30                                      Park
# 31                                 Westfalia
# 32                                       KSA
# 54                                   Sparkle
# 56                              Hotbox Brown
# 57                                      Gold
# 66                                Cafe Leche
# 67                    Damascene Apricot Sour
# 90                               Sex Panther
# 102                           Vanilla Porter
# 105                                     Gose
# 106                          Vermont Pilsner
# 134                      Ginger Peach Saison
# 139                            Weissenheimer
# ...

# %% [markdown]
# ## List the median IBUs of each type of beer. Graph it.
#
# Put the highest at the top, and the nan ones at the bottom. I want a nice graph, too - don't let them all be squished together, either!

# %%
df.groupby('Style')['IBUs'].median().sort_values(ascending=False)
# Out:
# Style
# American Barleywine                    96.0
# Russian Imperial Stout                 94.0
# American Double / Imperial IPA         91.0
# American Double / Imperial Pilsner     85.0
# American Black Ale                     73.0
# Belgian Strong Dark Ale                72.0
# American Strong Ale                    70.0
# American IPA                           69.0
# English Stout                          66.0
# American India Pale Lager              65.0
# Belgian IPA                            61.0
# English Barleywine                     60.0
# Rye Beer                               57.0
# Baltic Porter                          52.0
# English Strong Ale                     52.0
# American Double / Imperial Stout       51.0
# English India Pale Ale (IPA)           47.0
# American White IPA                     45.0
# American Pale Ale (APA)                44.0
# Extra Special / Strong Bitter (ESB)    41.0
# California Common / Steam Beer         41.0
# ...

# %%
df.groupby('Style')['IBUs'].median().sort_values(na_position='first').plot(kind='barh',figsize=(10,20))

# %%
df.groupby('Style')['IBUs'].median().dropna().sort_values().plot(kind='barh',figsize=(10,20))

# %% [markdown]
# ## Hmmmm, it looks like they are generally different styles. What are the most common 5 styles of high-IBU beer vs. low-IBU beer?
#
# You'll want to think about it in three pieces - finding the high IBU beers, then finding out what the most common styles are, then getting the top 5.

# %%
df.groupby('Style')['IBUs'].median().dropna().sort_values(ascending=False).head()
# Out:
# Style
# American Barleywine                   96.0
# Russian Imperial Stout                94.0
# American Double / Imperial IPA        91.0
# American Double / Imperial Pilsner    85.0
# American Black Ale                    73.0
# Name: IBUs, dtype: float64

# %%
df.groupby('Style')['IBUs'].median().dropna().sort_values(ascending=False).tail()
# Out:
# Style
# Hefeweizen                15.0
# Light Lager               12.0
# Gose                      10.0
# American Adjunct Lager     9.0
# Berliner Weissbier         8.0
# Name: IBUs, dtype: float64

# %% [markdown]
# ## Get the average IBU of "Witbier", "Hefeweizen" and "American Pale Wheat Ale" styles (also draw a histogram)
#
# I want ONE measurement and ONE graph, not three separate ones. And 20 to 30 bins in the histogram, please.

# %%
#get all the matches for these wheat beers
wheat = ["Witbier", "Hefeweizen", "American Pale Wheat Ale"]
wheat_df = df[df['Style'].isin(wheat)]

# %%
#find the average IBUs
wheat_df['IBUs'].mean()
# Out:
# 18.982142857142858

# %%
#plot a histogram of the wheat beer IBUs
wheat_df['IBUs'].hist(bins=20)

# %% [markdown]
# ## Get the average IBU of any style with "IPA" in it (also draw a histogram)

# %%
IPA_df = df[df['Style'].str.contains("IPA", na=False)]

# %%
IPA_df['IBUs'].mean()
# Out:
# 71.948979591836732

# %%
IPA_df['IBUs'].hist(bins=20)

# %% [markdown]
# ## Plot those two histograms on top of one another

# %%
ax = wheat_df['IBUs'].hist(bins=20, color='orange')
IPA_df['IBUs'].hist(bins=20, color= 'green', ax=ax, alpha=0.5)

# %% [markdown]
# ## Compare the ABV of wheat beers vs. IPAs

# %%
wheat_df[:5]
# Out:
#              Beer                       Brewery           Location  \
# 30           Park       Fort Point Beer Company  San Francisco, CA
# 42     Whitewater  Great Divide Brewing Company         Denver, CO
# 72    Citra Faced           Three Pints Brewing   Martinsville, IN
# 112  Summer Wheat        Anchor Brewing Company  San Francisco, CA
# 138   Waterkeeper    SweetWater Brewing Company        Atlanta, GA
#
#                        Style    Size    ABV  IBUs  ABV_new
# 30   American Pale Wheat Ale  12 oz.  4.70%  19.0      4.7
# 42   American Pale Wheat Ale  12 oz.  6.10%   NaN      6.1
# 72   American Pale Wheat Ale  16 oz.  5.50%  64.0      5.5
# 112  American Pale Wheat Ale  12 oz.  4.50%   NaN      4.5
# 138               Hefeweizen  12 oz.  5.70%   NaN      5.7

# %%
IPA_df[:5]
# Out:
#               Beer                    Brewery         Location  \
# 0     Get Together          NorthGate Brewing  Minneapolis, MN
# 6   Citra Ass Down  Against the Grain Brewery   Louisville, KY
# 14     Rico Sauvin  Against the Grain Brewery   Louisville, KY
# 17    Pile of Face  Against the Grain Brewery   Louisville, KY
# 24  Habitus (2014)  Mike Hess Brewing Company    San Diego, CA
#
#                              Style    Size    ABV   IBUs  ABV_new
# 0                     American IPA  16 oz.  4.50%   50.0      4.5
# 6   American Double / Imperial IPA  16 oz.  8.00%   68.0      8.0
# 14  American Double / Imperial IPA  16 oz.  7.60%   68.0      7.6
# 17                    American IPA  16 oz.  6.00%   65.0      6.0
# 24  American Double / Imperial IPA  16 oz.  8.00%  100.0      8.0

# %%
ax = wheat_df['ABV_new'].hist(bins=20, color='orange')
IPA_df['ABV_new'].hist(bins=20, color= 'green', ax=ax, alpha=0.5)
